# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
from pprint import pprint
import requests
import pymongo

# %%
pd_data = "data/nn_vote_data.csv"

# %%
url = 'https://api.open.fec.gov/v1/totals/by_entity/?per_page=100&sort_nulls_last=true&page=1&sort=end_date&cycle=2018&api_key=9QH5k3FDtBg269BU5FrLdXZMHd3y3w1lORI7lg2K&sort_hide_null=false'

# %%
response = requests.get(url).text
data_json = json.loads(response)

# %%
pprint(data_json)
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 24, 'page': 1, 'pages': 1, 'per_page': 100},
#  'results': [{'cumulative_candidate_disbursements': 1074507.0,
#               'cumulative_candidate_receipts': 278462.0,
#               'cumulative_pac_disbursements': 7396647.0,
#               'cumulative_pac_receipts': 57266203.0,
#               'cumulative_party_disbursements': 28988630.0,
#               'cumulative_party_receipts': 39003451.0,
#               'cycle': 2018,
#               'end_date': '2017-01-31'},
#              {'cumulative_candidate_disbursements': 1995443.0,
#               'cumulative_candidate_receipts': 431858.0,
#               'cumulative_pac_disbursements': 15419906.0,
#               'cumulative_pac_receipts': 119076970.0,
#               'cumulative_party_disbursements': 60780692.0,
#               'cumulative_party_receipts': 84745660.0,
#               'cycle': 2018,
#               'end_date': '2017-02-28'},
# ...

# %%
data_df = pd.DataFrame(data_json['results'])

# %%
data_df.head()
# Out:
#    cumulative_candidate_disbursements  cumulative_candidate_receipts  \
# 0                           1074507.0                       278462.0
# 1                           1995443.0                       431858.0
# 2                          70562646.0                    127418855.0
# 3                          72692909.0                    129492964.0
# 4                          97035962.0                    154260458.0
#
#    cumulative_pac_disbursements  cumulative_pac_receipts  \
# 0                     7396647.0               57266203.0
# 1                    15419906.0              119076970.0
# 2                    77188552.0              268404025.0
# 3                    82593820.0              335629096.0
# 4                   106536823.0              436137325.0
#
#    cumulative_party_disbursements  cumulative_party_receipts  cycle  \
# 0                      28988630.0                 39003451.0   2018
# ...

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db_ETL = client.ETL_db
summary_collection = db_ETL.summary

# %%
summary_collection.insert_many(data_df.to_dict('results'))

# %%
data = "data/nn_vote_data.csv"

# %%
nn_df = pd.read_csv(data)

# %%
nn_df.head()
# Out:
#              Name Chamber Party District      Total       Dems     Repubs  \
# 0    McCain, John  Senate     R     AZS1  $794,881         $0   $794,881
# 1  Hoyer, Steny H   House     D     MD05  $659,490   $659,490         $0
# 2     Upton, Fred   House     R     MI06  $631,000         $0   $631,000
# 3      Blunt, Roy  Senate     R     MOS1  $503,133         $0   $503,133
# 4     Barton, Joe   House     R     TX06  $495,309         $0   $495,309
#
#   Comcast Corp   AT&T Inc Verizon Communications  \
# 0    $121,902   $477,088               $195,891
# 1    $222,100   $249,150               $188,240
# 2    $222,200   $228,600               $180,200
# 3    $152,100   $192,675               $158,358
# 4    $131,000   $233,509               $130,800
#
#   March 2017 Vote on Internet Privacy
# 0                                 Yea
# 1                                 Nay
# 2                                 Yea
# 3                                 Yea
# ...

# %%
summary_collection.insert_many(nn_df.to_dict('results'))

# %%
url = 'https://api.open.fec.gov/v1/elections/?sort_nulls_last=false&page=1&state=Texas&cycle=2018&election_full=false&sort_null_only=false&api_key=9QH5k3FDtBg269BU5FrLdXZMHd3y3w1lORI7lg2K&office=senate&per_page=20&sort_hide_null=false&sort=-total_receipts'

# %%
response = requests.get(url).text
data_2_json = json.loads(response)

# %%
pprint(data_2_json)
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 0, 'page': 1, 'pages': 0, 'per_page': 20},
#  'results': []}

# %%
data_2_df = pd.DataFrame(data_2_json['results'])
